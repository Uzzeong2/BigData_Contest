# %% [markdown]
# # NS SHOP+ 판매실적 예측을 통한 편성 최적화 방안 도출

# %% [markdown]
# ### -팀명: B526

# %% [markdown]
# # 1. Data Preprocessing

# %% [markdown]
# #  1) Load Data

# %% [markdown]
# - 분석에 필요한 패키지 설치

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler

from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.model_selection import KFold

# %% [markdown]
# - 모델 학습을 위한 Train Data 불러오기
# - Train Data에서 필요 없는 변수 제거하기

# %%
df=pd.read_excel('train_925.xlsx')
print(df.columns)
x=df.drop(['Unnamed: 0', 'X', 'index', '방송일시', 'Date', 'year','min','exposure_time','M_code', 'M_new', 'Product_code', 
           'P_new', '상품명', 'group', 'sub', 'subsub',  'total_sales', 'cumsum'], axis=1)
y=df['cumsum']
x.info()
# Out:
# Index(['Unnamed: 0', 'X', 'index', '방송일시', 'Date', 'year', 'day', 'min',
#        'month', 'time', 'week', 'weekday', 'holiday', 'exposure_time',
#        'cum_expoT', 'M_code', 'M_new', 'Product_code', 'P_new', 'group0',
#        'group1', 'group2', '상품명', 'group', 'sub', 'subsub', 'unit_price',
#        'ilsibul', 'temp', 'cold_wave', 'heat_wave', 'precipitation', 'package',
#        'viewingrate', 'total_sales', 'cumsum'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35750 entries, 0 to 35749
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            35750 non-null  int64
#  1   month          35750 non-null  int64
#  2   time           35750 non-null  int64
#  3   week           35750 non-null  int64
#  4   weekday        35750 non-null  int64
#  5   holiday        35750 non-null  int64
#  6   cum_expoT      35750 non-null  float64
#  7   group0         35750 non-null  int64
#  8   group1         35750 non-null  int64
#  9   group2         35750 non-null  int64
#  10  unit_price     35750 non-null  float64
#  11  ilsibul        35750 non-null  int64
#  12  temp           35750 non-null  float64
#  13  cold_wave      35750 non-null  int64
#  14  heat_wave      35750 non-null  int64
#  15  precipitation  35750 non-null  float64
#  16  package        35750 non-null  float64
#  17  viewingrate    35750 non-null  float64
# dtypes: float64(6), int64(12)
# memory usage: 4.9 MB

# %% [markdown]
# - 학습을 적용시킬 Test Data 불러오기
# - Test Data에서 필요 없는 변수 제거하기

# %%
df2=pd.read_excel('real_test2020.xlsx')
print(df2.columns)
X_test2=df2.drop(['index', '방송일시', 'Date', 'year', 'min', '마더코드', 'M_new', '상품코드', 'P_new'
                 ,'상품명', '상품군', 'sub', 'subsub' ],axis=1)
print(X_test2.info())
# Out:
# Index(['index', '방송일시', 'Date', 'year', 'day', 'min', 'month', 'time', 'week',
#        'weekday', 'holiday', 'cum_expoT', '마더코드', 'M_new', '상품코드', 'P_new',
#        'group0', 'group1', 'group2', '상품명', '상품군', 'sub', 'subsub',
#        'unit_price', 'ilsibul', 'temp', 'cold_wave', 'heat_wave',
#        'precipitation', 'package'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2716 entries, 0 to 2715
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            2716 non-null   int64
#  1   month          2716 non-null   int64
#  2   time           2716 non-null   int64
#  3   week           2716 non-null   int64
#  4   weekday        2716 non-null   int64
#  5   holiday        2716 non-null   int64
#  6   cum_expoT      2716 non-null   float64
#  7   group0         2716 non-null   int64
#  8   group1         2716 non-null   int64
#  9   group2         2716 non-null   int64
#  10  unit_price     2716 non-null   float64
#  11  ilsibul        2716 non-null   int64
#  12  temp           2716 non-null   float64
#  13  cold_wave      2716 non-null   int64
#  14  heat_wave      2716 non-null   int64
#  15  precipitation  2716 non-null   float64
#  16  package        2716 non-null   float64
# dtypes: float64(5), int64(12)
# memory usage: 360.8 KB
# None

# %% [markdown]
# - 2019년 Data를 4:1 비율로 train과 validation으로 분할함
# - 파이썬 내 train_test_split 함수 사용

# %%
X_train, X_validation, y_train, y_validation=train_test_split(x, y, test_size=0.2,random_state=121)
print(X_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28600 entries, 35382 to 11586
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            28600 non-null  int64
#  1   month          28600 non-null  int64
#  2   time           28600 non-null  int64
#  3   week           28600 non-null  int64
#  4   weekday        28600 non-null  int64
#  5   holiday        28600 non-null  int64
#  6   cum_expoT      28600 non-null  float64
#  7   group0         28600 non-null  int64
#  8   group1         28600 non-null  int64
#  9   group2         28600 non-null  int64
#  10  unit_price     28600 non-null  float64
#  11  ilsibul        28600 non-null  int64
#  12  temp           28600 non-null  float64
#  13  cold_wave      28600 non-null  int64
#  14  heat_wave      28600 non-null  int64
#  15  precipitation  28600 non-null  float64
#  16  package        28600 non-null  float64
#  17  viewingrate    28600 non-null  float64
# dtypes: float64(6), int64(12)
# memory usage: 4.1 MB
# None

# %% [markdown]
# - 범주형 변수를 정제하기 위해 'make_column_transformer' 및 'OneHotEncoder' 함수 사용

# %%
transformer = make_column_transformer(

    (OneHotEncoder(), ['day','month','time','week','weekday','holiday','group0','group1','group2','ilsibul','cold_wave','heat_wave']),
    remainder='passthrough')

transformer.fit(x)
x=transformer.transform(x)
X_train= transformer.transform(X_train)
X_validation= transformer.transform(X_validation)

# %%
print(X_train.shape)
print(X_validation.shape)
# Out:
# (28600, 170)
# (7150, 170)

# %% [markdown]
# # 2) Predict viewingrate in 2020

# %% [markdown]
# ###### 2020 데이터에 시청률이 없으므로 2019 데이터로 훈련시켜 시청률 예측하여 넣어주어야 함.

# %%
df=pd.read_excel('train_925.xlsx')
print(df.columns)
x_view=df.drop(['Unnamed: 0', 'X', 'index', '방송일시', 'Date', 'year','min','exposure_time','M_code', 'M_new', 'Product_code', 
           'P_new', '상품명', 'group', 'sub', 'subsub',  'total_sales', 'cumsum','viewingrate'], axis=1)
y_view=df.viewingrate
x_view.info()
# Out:
# Index(['Unnamed: 0', 'X', 'index', '방송일시', 'Date', 'year', 'day', 'min',
#        'month', 'time', 'week', 'weekday', 'holiday', 'exposure_time',
#        'cum_expoT', 'M_code', 'M_new', 'Product_code', 'P_new', 'group0',
#        'group1', 'group2', '상품명', 'group', 'sub', 'subsub', 'unit_price',
#        'ilsibul', 'temp', 'cold_wave', 'heat_wave', 'precipitation', 'package',
#        'viewingrate', 'total_sales', 'cumsum'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35750 entries, 0 to 35749
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            35750 non-null  int64
#  1   month          35750 non-null  int64
#  2   time           35750 non-null  int64
#  3   week           35750 non-null  int64
#  4   weekday        35750 non-null  int64
#  5   holiday        35750 non-null  int64
#  6   cum_expoT      35750 non-null  float64
#  7   group0         35750 non-null  int64
#  8   group1         35750 non-null  int64
#  9   group2         35750 non-null  int64
#  10  unit_price     35750 non-null  float64
#  11  ilsibul        35750 non-null  int64
#  12  temp           35750 non-null  float64
#  13  cold_wave      35750 non-null  int64
#  14  heat_wave      35750 non-null  int64
#  15  precipitation  35750 non-null  float64
#  16  package        35750 non-null  float64
# dtypes: float64(5), int64(12)
# memory usage: 4.6 MB

# %%
X_train2, X_validation2, y_train2, y_validation2=train_test_split(x_view, y_view, test_size=0.2,random_state=121)
print(X_train2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28600 entries, 35382 to 11586
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            28600 non-null  int64
#  1   month          28600 non-null  int64
#  2   time           28600 non-null  int64
#  3   week           28600 non-null  int64
#  4   weekday        28600 non-null  int64
#  5   holiday        28600 non-null  int64
#  6   cum_expoT      28600 non-null  float64
#  7   group0         28600 non-null  int64
#  8   group1         28600 non-null  int64
#  9   group2         28600 non-null  int64
#  10  unit_price     28600 non-null  float64
#  11  ilsibul        28600 non-null  int64
#  12  temp           28600 non-null  float64
#  13  cold_wave      28600 non-null  int64
#  14  heat_wave      28600 non-null  int64
#  15  precipitation  28600 non-null  float64
#  16  package        28600 non-null  float64
# dtypes: float64(5), int64(12)
# memory usage: 3.9 MB
# None

# %% [markdown]
# - 범주형 변수를 정제하기 위해 'make_column_transformer' 및 'OneHotEncoder' 함수 사용

# %%
transformer2= make_column_transformer(

    (OneHotEncoder(), ['day','month','time','week','weekday','holiday','group0','group1','group2','ilsibul','cold_wave','heat_wave']),
    remainder='passthrough')

transformer2.fit(x_view)
x_view=transformer2.transform(x_view)
X_train2= transformer2.transform(X_train2)
X_validation2= transformer2.transform(X_validation2)
X_test2= transformer2.transform(X_test2)

# %% [markdown]
# - 원핫인코딩 후 shape 확인

# %%
print(X_train2.shape)
print(X_validation2.shape)
print(X_test2.shape)
# Out:
# (28600, 169)
# (7150, 169)
# (2716, 169)

# %% [markdown]
# - 시청률 예측에 가장 적절한 모델 결정을 위해 디폴트 상태에서 Gradient Boosting Model, XGBoost, LightGBM을 돌린 후 Best Score 확인
# - 가장 Best Sore가 높은 XGBoost

# %%
## 하이퍼파라미터

gb_reg=GradientBoostingRegressor()
xgb_reg=XGBRegressor()
lgb_reg=LGBMRegressor()

# %%
gb_reg.fit(X_train2, y_train2)
print("best score:{0:.4f}".format(gb_reg.score(X_validation2,y_validation2)))
# Out:
# best score:0.1222

# %%
xgb_reg.fit(X_train2, y_train2)
print("best score:{0:.4f}".format(xgb_reg.score(X_validation2,y_validation2)))
# Out:
# best score:0.4079

# %%
lgb_reg.fit(X_train2, y_train2)
print("best score:{0:.4f}".format(lgb_reg.score(X_validation2,y_validation2)))
# Out:
# best score:0.2532

# %%
#xgboost
params={
    'n_estimators':list(range(100,1500,100)),
    'max_depth':list(range(10,32,1)),
}

xgb_reg=XGBRegressor(random_state=121,n_jobs=-1)
grid_cv=GridSearchCV(xgb_reg,param_grid=params,cv=2,n_jobs=-1)
grid_cv.fit(X_train,y_train)
print("최적파라미터:\n",grid_cv.best_params_)
print("최고예측정확도:{0:.4f}".format(grid_cv.best_score_))
# Out:
# 최적파라미터:
#  {'max_depth': 10, 'n_estimators': 100}
# 최고예측정확도:0.7497

# %%
xgb_reg=XGBRegressor(max_depth= 10,n_estimators= 100)
xgb_reg.fit(X_train2, y_train2)
xgb_reg.score(X_validation2,y_validation2)
y_pred_view=xgb_reg.predict(X_test2) #여기서 y_pred가 2020년 viewingrate 예측치
y_pred_view=np.maximum(0,y_pred_view)

# %% [markdown]
# - 위에서 추정한 2020 시청률을 2020년 데이터에 붙임

# %%
df2=pd.read_excel('real_test2020.xlsx')
print(df2.columns)
X_test=df2.drop(['index', '방송일시', 'Date', 'year', 'min', '마더코드', 'M_new', '상품코드', 'P_new'
                 ,'상품명', '상품군', 'sub', 'subsub' ],axis=1)
# Out:
# Index(['index', '방송일시', 'Date', 'year', 'day', 'min', 'month', 'time', 'week',
#        'weekday', 'holiday', 'cum_expoT', '마더코드', 'M_new', '상품코드', 'P_new',
#        'group0', 'group1', 'group2', '상품명', '상품군', 'sub', 'subsub',
#        'unit_price', 'ilsibul', 'temp', 'cold_wave', 'heat_wave',
#        'precipitation', 'package'],
#       dtype='object')

# %%
y_pred_view=pd.DataFrame(y_pred_view)

# %%
X_test=pd.concat([X_test, y_pred_view], axis=1)
X_test.rename(columns={0:"viewingrate"}, inplace=True)

# %%
X_test= transformer.transform(X_test)
X_test.shape
# Out:
# (2716, 170)

# %% [markdown]
# # 2. Modeling

# %% [markdown]
# # 1) Hyperparameter Setting

# %% [markdown]
# - 파이썬 내 'GridSearchCV' 패키지를 이용하여 최고예측정확도를 가지는 하이퍼 파라미터를 구함

# %% [markdown]
# 1) Gradient Boosting Model

# %%
params={
    'n_estimators':list(range(500,1500,100)),
    'max_depth':list(range(10,32,1)),
}

gb_reg=XGBRegressor(random_state=121,n_jobs=-1)
grid_cv1=GridSearchCV(gb_reg,param_grid=params,cv=2,n_jobs=-1)
grid_cv1.fit(X_train,y_train)
print("최적파라미터:\n",grid_cv1.best_params_)
print("최고예측정확도:{0:.4f}".format(grid_cv1.best_score_))
# Out:
# 최적파라미터:
#  {'max_depth': 10, 'n_estimators': 600}
# 최고예측정확도:0.7481

# %% [markdown]
# 2) XGBoost

# %%
params={
    'n_estimators':list(range(500,1500,100)),
    'max_depth':list(range(5,20,1)),
    'min_child_weight':list(range(1,10,1))
}

xgb_reg=XGBRegressor(random_state=121,n_jobs=-1)
grid_cv2=GridSearchCV(xgb_reg,param_grid=params,cv=2,n_jobs=-1)
grid_cv2.fit(X_train,y_train)
print("최적파라미터:\n",grid_cv2.best_params_)
print("최고예측정확도:{0:.4f}".format(grid_cv2.best_score_))
# Out:
# 최적파라미터:
#  {'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 500}
# 최고예측정확도:0.7597

# %% [markdown]
# 3) LightGBM

# %%
params={
    'n_estimators':list(range(1000,1500,100)),
    'max_depth':list(range(10,32,1)),
    'num_leaves':list(range(10,30,2))
    
}
 
lgb_reg=LGBMRegressor(random_state=121,n_jobs=-1)
grid_cv3=GridSearchCV(lgb_reg,param_grid=params,cv=2,n_jobs=-1)
grid_cv3.fit(X_train,y_train)
print("최적파라미터:\n",grid_cv3.best_params_)
print("최고예측정확도:{0:.4f}".format(grid_cv3.best_score_))
# Out:
# 최적파라미터:
#  {'max_depth': 12, 'n_estimators': 1300, 'num_leaves': 26}
# 최고예측정확도:0.7751

# %% [markdown]
# - 최고 예측 정확도가 가장 높은 하이퍼 파라미터를 선택하여 모델에 적용 후 학습시키고자 함
# - 각 모형에 대한 Regressor 함수를 미리 이름으로 지정하여 편리하게 학습시키고자 함

# %% [markdown]
# # 2) 모델 학습

# %% [markdown]
# - Gradient Boosting Model, XGBoost, LightGBM 단일 모형과 두개씩 묶은 앙상블, 세개를 모두 묶은 앙상블 모형 학습

# %%
gb_reg=GradientBoostingRegressor(random_state=121,max_depth=10,n_estimators=600) 
xgb_reg=XGBRegressor(random_state=121,max_depth=7,min_child_weight=2,n_estimators=500) 
lgb_reg=LGBMRegressor(random_state=121,max_depth=12,n_estimators=1300,num_leaves=26)

# %% [markdown]
# 1) Gradient Boosting Model

# %%
gb_reg.fit(X_train, y_train)
y_pred=gb_reg.predict(X_validation)

a1=abs((y_pred-y_validation)/(y_validation))
print("MAPE:{0:.4f}".format(sum(a1)/7150))
print("Best Score:{0:.4f}".format(gb_reg.score(X_validation, y_validation)))
# Out:
# MAPE:0.5922
# Best Score:0.8173

# %% [markdown]
# 2) XGBoost

# %%
xgb_reg.fit(X_train, y_train, eval_set=[(X_validation, y_validation)], early_stopping_rounds=100)
y_pred=xgb_reg.predict(X_validation)

a1=abs((y_pred-y_validation)/(y_validation))
print("MAPE:{0:.4f}".format(sum(a1)/7150))
print("Best Score:{0:.4f}".format(xgb_reg.score(X_validation, y_validation)))
# Out:
# [0]	validation_0-rmse:0.29456
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [1]	validation_0-rmse:0.21105
# [2]	validation_0-rmse:0.15439
# [3]	validation_0-rmse:0.11651
# [4]	validation_0-rmse:0.09198
# [5]	validation_0-rmse:0.07681
# [6]	validation_0-rmse:0.06800
# [7]	validation_0-rmse:0.06299
# [8]	validation_0-rmse:0.06009
# [9]	validation_0-rmse:0.05858
# [10]	validation_0-rmse:0.05767
# [11]	validation_0-rmse:0.05702
# [12]	validation_0-rmse:0.05645
# [13]	validation_0-rmse:0.05589
# [14]	validation_0-rmse:0.05561
# [15]	validation_0-rmse:0.05540
# [16]	validation_0-rmse:0.05519
# [17]	validation_0-rmse:0.05490
# [18]	validation_0-rmse:0.05461
# [19]	validation_0-rmse:0.05435
# [20]	validation_0-rmse:0.05345
# [21]	validation_0-rmse:0.05333
# [22]	validation_0-rmse:0.05319
# [23]	validation_0-rmse:0.05303
# [24]	validation_0-rmse:0.05292
# [25]	validation_0-rmse:0.05282
# [26]	validation_0-rmse:0.05276
# [27]	validation_0-rmse:0.05266
# [28]	validation_0-rmse:0.05254
# [29]	validation_0-rmse:0.05238
# [30]	validation_0-rmse:0.05228
# [31]	validation_0-rmse:0.05218
# [32]	validation_0-rmse:0.05209
# [33]	validation_0-rmse:0.05179
# [34]	validation_0-rmse:0.05166
# [35]	validation_0-rmse:0.05159
# [36]	validation_0-rmse:0.05147
# [37]	validation_0-rmse:0.05117
# [38]	validation_0-rmse:0.05106
# [39]	validation_0-rmse:0.05100
# [40]	validation_0-rmse:0.05094
# [41]	validation_0-rmse:0.05084
# [42]	validation_0-rmse:0.05070
# [43]	validation_0-rmse:0.05047
# [44]	validation_0-rmse:0.05022
# [45]	validation_0-rmse:0.05008
# [46]	validation_0-rmse:0.05003
# [47]	validation_0-rmse:0.05001
# [48]	validation_0-rmse:0.05000
# [49]	validation_0-rmse:0.04991
# [50]	validation_0-rmse:0.04982
# [51]	validation_0-rmse:0.04981
# [52]	validation_0-rmse:0.04978
# [53]	validation_0-rmse:0.04970
# [54]	validation_0-rmse:0.04965
# [55]	validation_0-rmse:0.04958
# [56]	validation_0-rmse:0.04954
# [57]	validation_0-rmse:0.04947
# [58]	validation_0-rmse:0.04942
# [59]	validation_0-rmse:0.04939
# [60]	validation_0-rmse:0.04928
# [61]	validation_0-rmse:0.04923
# [62]	validation_0-rmse:0.04906
# [63]	validation_0-rmse:0.04878
# [64]	validation_0-rmse:0.04864
# [65]	validation_0-rmse:0.04864
# [66]	validation_0-rmse:0.04857
# [67]	validation_0-rmse:0.04856
# [68]	validation_0-rmse:0.04846
# [69]	validation_0-rmse:0.04836
# [70]	validation_0-rmse:0.04832
# [71]	validation_0-rmse:0.04816
# [72]	validation_0-rmse:0.04811
# [73]	validation_0-rmse:0.04800
# [74]	validation_0-rmse:0.04793
# [75]	validation_0-rmse:0.04786
# [76]	validation_0-rmse:0.04774
# [77]	validation_0-rmse:0.04767
# [78]	validation_0-rmse:0.04763
# [79]	validation_0-rmse:0.04755
# [80]	validation_0-rmse:0.04756
# [81]	validation_0-rmse:0.04748
# [82]	validation_0-rmse:0.04742
# [83]	validation_0-rmse:0.04729
# [84]	validation_0-rmse:0.04713
# [85]	validation_0-rmse:0.04707
# [86]	validation_0-rmse:0.04699
# [87]	validation_0-rmse:0.04698
# [88]	validation_0-rmse:0.04691
# [89]	validation_0-rmse:0.04686
# [90]	validation_0-rmse:0.04682
# [91]	validation_0-rmse:0.04678
# [92]	validation_0-rmse:0.04676
# [93]	validation_0-rmse:0.04668
# [94]	validation_0-rmse:0.04668
# [95]	validation_0-rmse:0.04661
# [96]	validation_0-rmse:0.04659
# [97]	validation_0-rmse:0.04653
# [98]	validation_0-rmse:0.04652
# [99]	validation_0-rmse:0.04645
# [100]	validation_0-rmse:0.04640
# [101]	validation_0-rmse:0.04635
# [102]	validation_0-rmse:0.04632
# [103]	validation_0-rmse:0.04631
# [104]	validation_0-rmse:0.04632
# [105]	validation_0-rmse:0.04623
# [106]	validation_0-rmse:0.04621
# [107]	validation_0-rmse:0.04619
# [108]	validation_0-rmse:0.04618
# [109]	validation_0-rmse:0.04610
# [110]	validation_0-rmse:0.04607
# [111]	validation_0-rmse:0.04591
# [112]	validation_0-rmse:0.04591
# [113]	validation_0-rmse:0.04593
# [114]	validation_0-rmse:0.04592
# [115]	validation_0-rmse:0.04589
# [116]	validation_0-rmse:0.04588
# [117]	validation_0-rmse:0.04588
# [118]	validation_0-rmse:0.04582
# [119]	validation_0-rmse:0.04579
# [120]	validation_0-rmse:0.04577
# [121]	validation_0-rmse:0.04576
# [122]	validation_0-rmse:0.04575
# [123]	validation_0-rmse:0.04574
# [124]	validation_0-rmse:0.04566
# [125]	validation_0-rmse:0.04560
# [126]	validation_0-rmse:0.04558
# [127]	validation_0-rmse:0.04548
# [128]	validation_0-rmse:0.04546
# [129]	validation_0-rmse:0.04547
# [130]	validation_0-rmse:0.04548
# [131]	validation_0-rmse:0.04542
# [132]	validation_0-rmse:0.04541
# [133]	validation_0-rmse:0.04541
# [134]	validation_0-rmse:0.04540
# [135]	validation_0-rmse:0.04537
# [136]	validation_0-rmse:0.04537
# [137]	validation_0-rmse:0.04538
# [138]	validation_0-rmse:0.04532
# [139]	validation_0-rmse:0.04525
# [140]	validation_0-rmse:0.04524
# [141]	validation_0-rmse:0.04522
# [142]	validation_0-rmse:0.04519
# [143]	validation_0-rmse:0.04519
# [144]	validation_0-rmse:0.04517
# [145]	validation_0-rmse:0.04516
# [146]	validation_0-rmse:0.04514
# [147]	validation_0-rmse:0.04510
# [148]	validation_0-rmse:0.04510
# [149]	validation_0-rmse:0.04506
# [150]	validation_0-rmse:0.04506
# [151]	validation_0-rmse:0.04504
# [152]	validation_0-rmse:0.04501
# [153]	validation_0-rmse:0.04498
# [154]	validation_0-rmse:0.04495
# [155]	validation_0-rmse:0.04494
# [156]	validation_0-rmse:0.04486
# [157]	validation_0-rmse:0.04485
# [158]	validation_0-rmse:0.04485
# [159]	validation_0-rmse:0.04483
# [160]	validation_0-rmse:0.04482
# [161]	validation_0-rmse:0.04479
# [162]	validation_0-rmse:0.04477
# [163]	validation_0-rmse:0.04477
# [164]	validation_0-rmse:0.04474
# [165]	validation_0-rmse:0.04474
# [166]	validation_0-rmse:0.04473
# [167]	validation_0-rmse:0.04473
# [168]	validation_0-rmse:0.04472
# [169]	validation_0-rmse:0.04473
# [170]	validation_0-rmse:0.04470
# [171]	validation_0-rmse:0.04467
# [172]	validation_0-rmse:0.04466
# [173]	validation_0-rmse:0.04467
# [174]	validation_0-rmse:0.04465
# [175]	validation_0-rmse:0.04462
# [176]	validation_0-rmse:0.04459
# [177]	validation_0-rmse:0.04455
# [178]	validation_0-rmse:0.04454
# [179]	validation_0-rmse:0.04456
# [180]	validation_0-rmse:0.04455
# [181]	validation_0-rmse:0.04455
# [182]	validation_0-rmse:0.04451
# [183]	validation_0-rmse:0.04446
# [184]	validation_0-rmse:0.04444
# [185]	validation_0-rmse:0.04442
# [186]	validation_0-rmse:0.04441
# [187]	validation_0-rmse:0.04441
# [188]	validation_0-rmse:0.04441
# [189]	validation_0-rmse:0.04441
# [190]	validation_0-rmse:0.04438
# [191]	validation_0-rmse:0.04438
# [192]	validation_0-rmse:0.04434
# [193]	validation_0-rmse:0.04431
# [194]	validation_0-rmse:0.04429
# [195]	validation_0-rmse:0.04429
# [196]	validation_0-rmse:0.04429
# [197]	validation_0-rmse:0.04426
# [198]	validation_0-rmse:0.04427
# [199]	validation_0-rmse:0.04425
# [200]	validation_0-rmse:0.04425
# [201]	validation_0-rmse:0.04424
# [202]	validation_0-rmse:0.04422
# [203]	validation_0-rmse:0.04421
# [204]	validation_0-rmse:0.04422
# [205]	validation_0-rmse:0.04423
# [206]	validation_0-rmse:0.04422
# [207]	validation_0-rmse:0.04421
# [208]	validation_0-rmse:0.04421
# [209]	validation_0-rmse:0.04421
# [210]	validation_0-rmse:0.04419
# [211]	validation_0-rmse:0.04417
# [212]	validation_0-rmse:0.04418
# [213]	validation_0-rmse:0.04418
# [214]	validation_0-rmse:0.04416
# [215]	validation_0-rmse:0.04415
# [216]	validation_0-rmse:0.04414
# [217]	validation_0-rmse:0.04414
# [218]	validation_0-rmse:0.04416
# [219]	validation_0-rmse:0.04414
# [220]	validation_0-rmse:0.04409
# [221]	validation_0-rmse:0.04408
# [222]	validation_0-rmse:0.04406
# [223]	validation_0-rmse:0.04405
# [224]	validation_0-rmse:0.04403
# [225]	validation_0-rmse:0.04403
# [226]	validation_0-rmse:0.04403
# [227]	validation_0-rmse:0.04403
# [228]	validation_0-rmse:0.04402
# [229]	validation_0-rmse:0.04401
# [230]	validation_0-rmse:0.04401
# [231]	validation_0-rmse:0.04399
# [232]	validation_0-rmse:0.04396
# [233]	validation_0-rmse:0.04395
# [234]	validation_0-rmse:0.04388
# [235]	validation_0-rmse:0.04386
# [236]	validation_0-rmse:0.04386
# [237]	validation_0-rmse:0.04385
# [238]	validation_0-rmse:0.04382
# [239]	validation_0-rmse:0.04380
# [240]	validation_0-rmse:0.04379
# [241]	validation_0-rmse:0.04380
# [242]	validation_0-rmse:0.04379
# [243]	validation_0-rmse:0.04379
# [244]	validation_0-rmse:0.04380
# [245]	validation_0-rmse:0.04380
# [246]	validation_0-rmse:0.04380
# [247]	validation_0-rmse:0.04379
# [248]	validation_0-rmse:0.04375
# [249]	validation_0-rmse:0.04374
# [250]	validation_0-rmse:0.04373
# [251]	validation_0-rmse:0.04371
# [252]	validation_0-rmse:0.04371
# [253]	validation_0-rmse:0.04369
# [254]	validation_0-rmse:0.04368
# [255]	validation_0-rmse:0.04369
# [256]	validation_0-rmse:0.04367
# [257]	validation_0-rmse:0.04366
# [258]	validation_0-rmse:0.04367
# [259]	validation_0-rmse:0.04364
# [260]	validation_0-rmse:0.04366
# [261]	validation_0-rmse:0.04365
# [262]	validation_0-rmse:0.04365
# [263]	validation_0-rmse:0.04364
# [264]	validation_0-rmse:0.04363
# [265]	validation_0-rmse:0.04365
# [266]	validation_0-rmse:0.04362
# [267]	validation_0-rmse:0.04362
# [268]	validation_0-rmse:0.04359
# [269]	validation_0-rmse:0.04361
# [270]	validation_0-rmse:0.04362
# [271]	validation_0-rmse:0.04364
# [272]	validation_0-rmse:0.04364
# [273]	validation_0-rmse:0.04365
# [274]	validation_0-rmse:0.04364
# [356]	validation_0-rmse:0.04337
# [357]	validation_0-rmse:0.04337
# [358]	validation_0-rmse:0.04337
# [359]	validation_0-rmse:0.04338
# [360]	validation_0-rmse:0.04338
# [361]	validation_0-rmse:0.04337
# [362]	validation_0-rmse:0.04337
# [363]	validation_0-rmse:0.04336
# [364]	validation_0-rmse:0.04337
# [365]	validation_0-rmse:0.04336
# [366]	validation_0-rmse:0.04336
# [367]	validation_0-rmse:0.04335
# [368]	validation_0-rmse:0.04335
# [369]	validation_0-rmse:0.04335
# [370]	validation_0-rmse:0.04335
# [371]	validation_0-rmse:0.04335
# [372]	validation_0-rmse:0.04335
# [373]	validation_0-rmse:0.04334
# [374]	validation_0-rmse:0.04332
# [375]	validation_0-rmse:0.04333
# [376]	validation_0-rmse:0.04332
# [377]	validation_0-rmse:0.04331
# [378]	validation_0-rmse:0.04332
# [379]	validation_0-rmse:0.04332
# [380]	validation_0-rmse:0.04332
# [381]	validation_0-rmse:0.04331
# [382]	validation_0-rmse:0.04331
# [383]	validation_0-rmse:0.04331
# [384]	validation_0-rmse:0.04331
# [385]	validation_0-rmse:0.04329
# [386]	validation_0-rmse:0.04329
# [387]	validation_0-rmse:0.04329
# [388]	validation_0-rmse:0.04328
# [389]	validation_0-rmse:0.04327
# [390]	validation_0-rmse:0.04327
# [391]	validation_0-rmse:0.04327
# [392]	validation_0-rmse:0.04327
# [393]	validation_0-rmse:0.04327
# [394]	validation_0-rmse:0.04327
# [395]	validation_0-rmse:0.04326
# [396]	validation_0-rmse:0.04325
# [397]	validation_0-rmse:0.04325
# [398]	validation_0-rmse:0.04324
# [399]	validation_0-rmse:0.04325
# [400]	validation_0-rmse:0.04326
# [401]	validation_0-rmse:0.04326
# [402]	validation_0-rmse:0.04326
# [403]	validation_0-rmse:0.04325
# [404]	validation_0-rmse:0.04327
# [405]	validation_0-rmse:0.04328
# [406]	validation_0-rmse:0.04328
# [407]	validation_0-rmse:0.04327
# [408]	validation_0-rmse:0.04327
# [409]	validation_0-rmse:0.04327
# [410]	validation_0-rmse:0.04326
# [411]	validation_0-rmse:0.04326
# [412]	validation_0-rmse:0.04326
# [413]	validation_0-rmse:0.04326
# [414]	validation_0-rmse:0.04326
# [415]	validation_0-rmse:0.04326
# [416]	validation_0-rmse:0.04326
# [417]	validation_0-rmse:0.04325
# [418]	validation_0-rmse:0.04325
# [419]	validation_0-rmse:0.04325
# [420]	validation_0-rmse:0.04325
# [421]	validation_0-rmse:0.04326
# [422]	validation_0-rmse:0.04326
# [423]	validation_0-rmse:0.04326
# [424]	validation_0-rmse:0.04325
# [425]	validation_0-rmse:0.04325
# [426]	validation_0-rmse:0.04323
# [427]	validation_0-rmse:0.04323
# [428]	validation_0-rmse:0.04323
# [429]	validation_0-rmse:0.04322
# [430]	validation_0-rmse:0.04322
# [431]	validation_0-rmse:0.04321
# [432]	validation_0-rmse:0.04322
# [433]	validation_0-rmse:0.04321
# [434]	validation_0-rmse:0.04321
# [435]	validation_0-rmse:0.04319
# [436]	validation_0-rmse:0.04319
# [437]	validation_0-rmse:0.04319
# [438]	validation_0-rmse:0.04319
# [439]	validation_0-rmse:0.04319
# [440]	validation_0-rmse:0.04319
# [441]	validation_0-rmse:0.04319
# [442]	validation_0-rmse:0.04319
# [443]	validation_0-rmse:0.04319
# [444]	validation_0-rmse:0.04319
# [445]	validation_0-rmse:0.04319
# [446]	validation_0-rmse:0.04318
# [447]	validation_0-rmse:0.04317
# [448]	validation_0-rmse:0.04318
# [449]	validation_0-rmse:0.04318
# [450]	validation_0-rmse:0.04317
# [451]	validation_0-rmse:0.04318
# [452]	validation_0-rmse:0.04318
# [453]	validation_0-rmse:0.04317
# [454]	validation_0-rmse:0.04317
# [455]	validation_0-rmse:0.04318
# [456]	validation_0-rmse:0.04318
# [457]	validation_0-rmse:0.04318
# [458]	validation_0-rmse:0.04318
# [459]	validation_0-rmse:0.04318
# [460]	validation_0-rmse:0.04318
# [461]	validation_0-rmse:0.04319
# [462]	validation_0-rmse:0.04319
# [463]	validation_0-rmse:0.04318
# [464]	validation_0-rmse:0.04319
# [465]	validation_0-rmse:0.04319
# [466]	validation_0-rmse:0.04317
# [467]	validation_0-rmse:0.04317
# [468]	validation_0-rmse:0.04317
# [469]	validation_0-rmse:0.04317
# [470]	validation_0-rmse:0.04317
# [471]	validation_0-rmse:0.04317
# [472]	validation_0-rmse:0.04317
# [473]	validation_0-rmse:0.04317
# [474]	validation_0-rmse:0.04318
# [475]	validation_0-rmse:0.04317
# [476]	validation_0-rmse:0.04319
# [477]	validation_0-rmse:0.04318
# [478]	validation_0-rmse:0.04318
# [479]	validation_0-rmse:0.04318
# [480]	validation_0-rmse:0.04318
# [481]	validation_0-rmse:0.04318
# [482]	validation_0-rmse:0.04317
# [483]	validation_0-rmse:0.04318
# [484]	validation_0-rmse:0.04318
# [485]	validation_0-rmse:0.04318
# [486]	validation_0-rmse:0.04319
# [487]	validation_0-rmse:0.04318
# [488]	validation_0-rmse:0.04318
# [489]	validation_0-rmse:0.04317
# [490]	validation_0-rmse:0.04318
# [491]	validation_0-rmse:0.04317
# [492]	validation_0-rmse:0.04317
# [493]	validation_0-rmse:0.04317
# [494]	validation_0-rmse:0.04317
# [495]	validation_0-rmse:0.04317
# [496]	validation_0-rmse:0.04317
# [497]	validation_0-rmse:0.04318
# [498]	validation_0-rmse:0.04318
# [499]	validation_0-rmse:0.04317
# MAPE:0.6568
# Best Score:0.8203

# %% [markdown]
# 3) LightGBM

# %%
lgb_reg.fit(X_train, y_train, eval_set=[(X_validation, y_validation)])
y_pred=lgb_reg.predict(X_validation)

a1=abs((y_pred-y_validation)/(y_validation))
print("MAPE:{0:.4f}".format(sum(a1)/7150))
print("Best Score:{0:.4f}".format(lgb_reg.score(X_validation, y_validation)))
# Out:
# [1]	valid_0's l2: 0.00930952
# [2]	valid_0's l2: 0.00844526
# [3]	valid_0's l2: 0.00773636
# [4]	valid_0's l2: 0.00714899
# [5]	valid_0's l2: 0.00666507
# [6]	valid_0's l2: 0.00625893
# [7]	valid_0's l2: 0.00592072
# [8]	valid_0's l2: 0.00564129
# 4) GB & XGB

# %%
named_estimators = [
    ("gb_reg", gb_reg),
    ("xgb_reg", xgb_reg)
]

vr2_1 = VotingRegressor(named_estimators)
vr2_1.fit(X_train, y_train)
y_pred2_1=vr2_1.predict(X_validation)
a2_1=abs((y_pred2_1-y_validation)/y_validation)
 
print("MAPE:{0:.4f}".format(sum(a2_1)/7150))
print("Best Score:{0:.4f}".format(vr2_1.score(X_validation, y_validation)))
# Out:
# MAPE:0.5873
# Best Score:0.8292

# %% [markdown]
# 5) GB & LGB

# %%
named_estimators = [
    ("gb_reg", gb_reg),
    ("lgb_reg", lgb_reg)
]

vr2_2 = VotingRegressor(named_estimators)
vr2_2.fit(X_train, y_train)
y_pred2_2=vr2_2.predict(X_validation)
a2_2=abs((y_pred2_2-y_validation)/y_validation)
 
print("MAPE:{0:.4f}".format(sum(a2_2)/7150))
print("Best Score:{0:.4f}".format(vr2_2.score(X_validation, y_validation)))
# Out:
# MAPE:0.6030
# Best Score:0.8349

# %% [markdown]
# 6) XGB & LGB

# %%
named_estimators = [
    ("xgb_reg", xgb_reg),
    ("lgb_reg", lgb_reg)
]

vr2_3 = VotingRegressor(named_estimators)
vr2_3.fit(X_train, y_train)
y_pred2_3=vr2_3.predict(X_validation)
a2_3=abs((y_pred2_3-y_validation)/y_validation)
 
print("MAPE:{0:.4f}".format(sum(a2_3)/7150))
print("Best Score:{0:.4f}".format(vr2_3.score(X_validation, y_validation)))
# Out:
# MAPE:0.6332
# Best Score:0.8350

# %% [markdown]
# 7) GB & XGB & LGB

# %%
named_estimators = [
    ("gb_reg", gb_reg),
    ("xgb_reg", xgb_reg),
    ("lgb_reg", lgb_reg)
]

vr3 = VotingRegressor(named_estimators)
vr3.fit(X_train, y_train)
y_pred3=vr3.predict(X_validation)
a3=abs((y_pred3-y_validation)/y_validation)
 
print("MAPE:{0:.4f}".format(sum(a3)/7150))
print("Best Score:{0:.4f}".format(vr3.score(X_validation, y_validation)))
# Out:
# MAPE:0.5949
# Best Score:0.8368

# %% [markdown]
# # 3) Stacking

# %% [markdown]
# - 예측 모형의 성능을 향상시키기 위해 학습시킨 앙상블 모델들 중 가장 우수한 모델 3개를 골라 stacking 사용
# - Stacking을 사용해서 2020년 6월의 상품별 누적합의 예측치를 구함

# %%
from sklearn.model_selection import KFold
def get_stacking_data(model, X_train,y_train, X_val,X_test, n_folds=10):
    kfold=KFold(n_splits=n_folds, random_state=None)
    
    train_fold_predict=np.zeros((X_train.shape[0],1))
    test_predict1=np.zeros((X_val.shape[0], n_folds))
    test_predict2=np.zeros((X_test.shape[0], n_folds))
    print("model :", model.__class__.__name__)
    
    for cnt, (train_index , valid_index) in enumerate(kfold.split(X_train,y_train)):
        X_train_=X_train[train_index]
        y_train_=y_train[train_index]
        X_validation=X_train[valid_index]
        y_validation=y_train[valid_index]
        
        model.fit(X_train_, y_train_)
        
        train_fold_predict[valid_index,:]=model.predict(X_validation).reshape(-1,1)
        
        test_predict1[:,cnt]=model.predict(X_val)
        test_predict2[:,cnt]=model.predict(X_test)
        
    test_predict_mean1= np.mean(test_predict1,axis=1).reshape(-1,1)
    test_predict_mean2= np.mean(test_predict2,axis=1).reshape(-1,1)
    return train_fold_predict, test_predict_mean1, test_predict_mean2

# %%
XX=X_train.toarray()
XX.shape
yy=pd.Series.to_numpy(y_train)
yy.shape
# Out:
# (28600,)

# %%
vr2_1train, vr2_1val, vr2_1test=get_stacking_data(vr2_1, XX,yy, X_validation, X_test, n_folds=10)
vr2_2train, vr2_2val, vr2_2test=get_stacking_data(vr2_2, XX,yy, X_validation, X_test, n_folds=10)
vr2_3train, vr2_3val, vr2_3test=get_stacking_data(vr2_3, XX,yy, X_validation, X_test, n_folds=10)

new_X_train=np.concatenate((vr2_1train,vr2_2train,vr2_3train), axis=1)
new_X_val=np.concatenate((vr2_1val,vr2_2val,vr2_3val), axis=1)
new_X_test=np.concatenate((vr2_1test,vr2_2test,vr2_3test), axis=1)
# Out:
# model : VotingRegressor
# model : VotingRegressor
# model : VotingRegressor

# %% [markdown]
# - 스태킹으로 구한 예측치와 y_validation 사이의 MAPE를 구함

# %%
gb_reg.fit(new_X_train, y_train)
score=gb_reg.score(new_X_val, y_validation)
stack_pred=gb_reg.predict(new_X_test)
y_pred=gb_reg.predict(new_X_val)
a=abs((y_pred-y_validation)/y_validation)
mape=sum(a)/7150

print("MAPE:{0:.4f}".format(sum(a)/7150))
print("Best Score:{0:.4f}".format(gb_reg.score(new_X_val, y_validation)))
# Out:
# MAPE:0.6016
# Best Score:0.8427

# %% [markdown]
# ### - 2020년 매출 예측치

# %%
a=pd.DataFrame(stack_pred)
a.to_csv("predict_2020.csv")

# %% [markdown]
# # 3. 요일별 / 시간별 최적화 방안 찾기

# %%
X_test3=pd.read_excel('broadcast_final.xlsx')
print(X_test3.columns)
# Out:
# Index(['index', 'day', 'month', 'time', 'week', 'weekday', 'holiday',
#        'cum_expoT', 'Product_group', 'sub', 'subsub', 'group0', 'group1',
#        'group2', 'unit_price', 'ilsibul', 'temp', 'cold_wave', 'heat_wave',
#        'precipitation', 'package', 'viewingrate'],
#       dtype='object')

# %%
x_broad=X_test3.drop(['index', 'Product_group', 'sub', 'subsub'], axis=1)

# %%
X_broad=transformer.transform(x_broad)

# %% [markdown]
# - 요일별 / 시간별 최적화를 위한 cumsum prediction
# - 위에서 적합시켰던 스태킹 모델을 사용하고, test data만 방금 불러온 'broadcast' 파일을 사용함.

# %%
vr2_1train, vr2_1val, vr2_1test=get_stacking_data(vr2_1, XX,yy, X_validation, X_broad, n_folds=10)
vr2_2train, vr2_2val, vr2_2test=get_stacking_data(vr2_2, XX,yy, X_validation, X_broad, n_folds=10)
vr2_3train, vr2_3val, vr2_3test=get_stacking_data(vr2_3, XX,yy, X_validation, X_broad, n_folds=10)

new_X_test3=np.concatenate((vr2_1test,vr2_2test,vr2_3test), axis=1)
# Out:
# model : VotingRegressor
# model : VotingRegressor
# model : VotingRegressor

# %%
stack_pred3=gb_reg.predict(new_X_test3)

# %%
b=pd.DataFrame(stack_pred3)
b.to_csv("broadcast_max.csv")
